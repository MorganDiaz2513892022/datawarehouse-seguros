# %% [markdown]
# <a href="https://colab.research.google.com/github/MorganDiaz2513892022/datawarehouse-seguros/blob/main/notebook/corredores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://raw.githubusercontent.com/MorganDiaz2513892022/datawarehouse-seguros/refs/heads/main/data/corredores.csv

# %%
import pandas as pd

# %%
url_corredores = "https://raw.githubusercontent.com/MorganDiaz2513892022/datawarehouse-seguros/refs/heads/main/data/corredores.csv"

# %%
corredores = pd.read_csv(url_corredores)

# %%
#exploracion de datos
corredores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_corredor        80 non-null     int64
#  1   nombre             80 non-null     object
#  2   zona               63 non-null     object
#  3   nivel              68 non-null     object
#  4   anios_experiencia  76 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 3.3+ KB

# %%
#limpieza general de datos
def limpiar_dataframe(df):
    df.columns = df.columns.str.strip().str.lower()
    for col in df.select_dtypes(include='object').columns:
        df[col] = df[col].astype(str).str.strip()
    df = df.replace(r'^\s*$', pd.NA, regex=True)
    df = df.drop_duplicates()
    return df

# %%
#exportacion de csv
corredores.to_csv("corredores_curated.csv", index=False)

# %%
#conexion de php con postgress
# !pip install sqlalchemy psycopg2-binary

from sqlalchemy import create_engine
import pandas as pd

database_url = "postgresql://etl_morgan:S7yYDjkaqdLgbyVUSdAYsSFjRQdzLb7F@dpg-d6uurindiees73co9gvg-a.oregon-postgres.render.com/elt_corredores"

engine = create_engine(database_url)

test = pd.read_sql("SELECT 1", engine)

print(test)
# Out:
# ...
#    ?column?
# 0         1

# %%
#cargar datos en la nube
corredores.to_sql('corredores', engine, if_exists='append', index=False)
# Out:
# 80

# %%
#comprobacion de tabla
df = pd.read_csv(url_corredores)

df.head()
# Out:
#    id_corredor               nombre         zona    nivel  anios_experiencia
# 0            1    José López Flores  Paracentral      Mid                4.0
# 1            2    José Ortiz García     Centro     Junior                0.0
# 2            3   María Ramírez Cruz       Centro  SENIOR                 6.0
# 3            4  Fernanda Rojas Cruz          NaN  SENIOR                 8.0
# 4            5      Ana Gómez Rojas          NaN   Senior                4.0
