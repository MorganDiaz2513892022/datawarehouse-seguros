# %% [markdown]
# <a href="https://colab.research.google.com/github/MorganDiaz2513892022/datawarehouse-seguros/blob/main/notebook/etl_aseguradoras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://raw.githubusercontent.com/MorganDiaz2513892022/etl-dataset-pipeline/refs/heads/main/data/raw/aseguradoras.csv

# %%
import pandas as pd

# %%
url_aseguradoras = "https://raw.githubusercontent.com/MorganDiaz2513892022/etl-dataset-pipeline/refs/heads/main/data/raw/aseguradoras.csv"

# %%
aseguradoras = pd.read_csv(url_aseguradoras)

# %%
aseguradoras.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id_aseguradora  15 non-null     int64
#  1   nombre          15 non-null     object
#  2   pais            13 non-null     object
#  3   rating_riesgo   12 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 612.0+ bytes

# %%
#limpieza general de datos
def limpiar_dataframe(df):

    df.columns = df.columns.str.strip().str.lower()

    for col in df.select_dtypes(include='object').columns:
        df[col] = df[col].astype(str).str.strip()

    df = df.replace(r'^\s*$', pd.NA, regex=True)

    df = df.drop_duplicates()

    return df

# %%
#exportacion de archivos
aseguradoras.to_csv("aseguradoras_curated.csv", index=False)

# %%
#creacion de tabla en postgres
# !pip install sqlalchemy psycopg2-binary

from sqlalchemy import create_engine

engine = create_engine(
"postgresql://etl_aseguradoras_user:bVZj4vML7WB9WB3W7zVm8z3UZbiVqN4E@dpg-d6r03o1aae7s739o00ng-a.oregon-postgres.render.com/etl_aseguradoras"
)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 73.8 MB/s eta 0:00:00
# ...

# %%
#carga de datos en la nube
aseguradoras.to_sql('aseguradoras', engine, if_exists='append', index=False)
# Out:
# 15
